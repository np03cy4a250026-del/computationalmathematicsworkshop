# %% [markdown]
# <a href="https://colab.research.google.com/github/np03cy4a250026-del/computationalmathematicsworkshop/blob/main/math_workshop_01.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ## *Name: Shudarsan Chaulagai*
# ## *University id: 2603727*

# %%
length = 3
breadth = 4
area = length * breadth
print(area)
# Out:
# 12

# %%
##  implicit conversion
print(2*3.5)
# Out:
# 7.0

# %%
## explicit conversin
length = 4.5
breadth = 5
area = length * breadth
print("area is " + str(area))
# Out:
# area is 22.5

# %%
hrs= input("enter the hours: ")
h = float(hrs)
rate = input("enter the rate: ")
r = float(rate)
if (h <= 40):
  pay = h * r
else:
  pay = (40 * r) +((h-40) * r * 1.5)
print("pay is", pay)
# Out:
# enter the hours: 45
# enter the rate: 10.50
# pay is 498.75

# %%
def greetings (name):
  print("welcome " + name)
greetings("shudarsan")
# Out:
# welcome shudarsan

# %%
def area_triangle(base, height):
  area = 0.5 * base * height
  return area
result=area_triangle(5, 4)
print(result)
# Out:
# 10.0

# %%
#6
def order_numbers(number1, number2):
	if number2 > number1:
		return number1, number2
	else:
		return number2, number1
smaller, bigger= order_numbers(33,44)
print(smaller,bigger)
# Out:
# 33 44

# %%
#7
def is_Even(number):
    if (number%2 == 0):
      return True
    return False
is_Even(5)
# Out:
# False

# %%
#8
def number_group(number):
  if number > 0:
    return "Positive"
  elif number == 0:
    return "Zero"
  else:
    return "Negative"
print(number_group(4)) #Should be Positive
print(number_group(0)) #Should be Zero
print(number_group(-8)) #Should be Negative
# Out:
# Positive
# Zero
# Negative

# %%
#9
x = 0 # initialzation of variable Why=?
while x<5:
  print("Not there yet, x= " + str(x))
  x = x+1
print("x= "+str(x))
# Out:
# Not there yet, x= 0
# Not there yet, x= 1
# Not there yet, x= 2
# Not there yet, x= 3
# Not there yet, x= 4
# x= 5

# %%
#10
def count_down(start_number):
  current=3 #initialzation of variable
  while (current > 0):
    print(current)
    current -= 1
print("Zero!")
count_down(3) #output=??
# Out:
# Zero!
# 3
# 2
# 1

# %%
#Example-11
if x != 0:
  while x%2 == 0:
    x = x/2
#or
while x != 0 and x%2 == 0:
  x = x/2

# %%
#13
# for loop, iterates over a sequence of values
for x in range(5):
  print(x)
# Out:
# 0
# 1
# 2
# 3
# 4

# %%
#14
def square(n):
  return n*n
def sum_squares(x):
  sum = 0
  for n in range(10):
    sum += square(n)
    return sum
print(sum_squares(10))
# Out:
# 0

# %%
#15
values = [10, 20, 30, 40, 50]
Sum = 0
length = 0
for value in values:
  Sum = Sum+value
length = length+1
print("Total sum= "+str(Sum)+"and the Average="+str(Sum/length))
# Out:
# Total sum= 150and the Average=150.0

# %% [markdown]
# 1.Write a function fib (n) that prompts the number of terms “n” from the user and
# displays first “n” terms of Fibonacci sequence iteratively.

# %%
n = input("Enter a no.")
n = int(n)
def fib(n):
 a = 0
 b = 1
 i = 0
 while i < n:
  print(a)
  c = a+b
  a = b
  b = c
  i = i +1
fib(n)
# Out:
# Enter a no.2
# 0
# 1

# %%
#c
def SumDigits(n):
    total = 0
    while n > 0:
        total += n % 10
        n //= 10
    print(total)

SumDigits(234)
# Out:
# 9

# %%
#d
def squaredSum(a):
  sum = 0
  i = 0
  for value in a:
    sum += value * value
  return sum
values = [2,3,4]
print(squaredSum(values))
# Out:
# 29

# %%
#e
def sumDigits(a):
  sum = 0
  i = 0
  for value in range(a+1):
    sum += value
  return sum
print(sumDigits(6))
# Out:
# 21
